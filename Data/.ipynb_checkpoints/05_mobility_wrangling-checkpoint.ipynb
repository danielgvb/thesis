# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
path = 'mobility/'
csv_files = os.listdir(path)
csv_files
# Out:
# ['CHL.csv', 'COL.csv', 'ITA.csv', 'MEX.csv', 'PAN.csv', 'USA.csv']

# %%
df = pd.read_csv(path + csv_files[0])
df[['Mean_distance_avg', 'Mean_distance_avg_14day_movavg']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1637 entries, 0 to 1636
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Mean_distance_avg               1595 non-null   float64
#  1   Mean_distance_avg_14day_movavg  1624 non-null   float64
# dtypes: float64(2)
# memory usage: 25.7 KB

# %%
df.tail()
# Out:
#             Date  Sample_size  Mean_distance_p5  Mean_distance_avg  \
# 1632  2024-08-29      94731.0             25.22              26.21
# 1633  2024-08-30      95964.0             27.83              28.55
# 1634  2024-08-31     101191.0             24.85              25.76
# 1635  2024-09-01      94711.0             21.09              21.85
# 1636  2024-09-02     100838.0             25.72              26.61
#
#       Mean_distance_p95  Mean_distance_p5_7day_movavg  \
# 1632              27.52                         25.84
# 1633              29.23                         26.65
# 1634              27.13                         26.34
# 1635              22.64                         25.39
# 1636              27.77                         25.54
#
#       Mean_distance_avg_7day_movavg  Mean_distance_p95_7day_movavg  \
# 1632                          26.13                          26.50
# 1633                          26.94                          27.27
# 1634                          26.64                          27.02
# 1635                          25.68                          26.05
# 1636                          25.84                          26.21
#
#       Mean_distance_p5_14day_movavg  Mean_distance_avg_14day_movavg  ...  \
# 1632                          24.91                           25.10  ...
# 1633                          25.28                           25.47  ...
# 1634                          25.64                           25.84  ...
# 1635                          25.49                           25.68  ...
# 1636                          25.51                           25.71  ...
#
#       At_home_p95_7day_movavg  At_home_p5_14day_movavg  \
# 1632                    22.23                    26.60
# 1633                    21.80                    25.73
# 1634                    22.81                    24.94
# 1635                    25.40                    24.34
# 1636                    24.69                    24.07
#
#       At_home_avg_14day_movavg  At_home_p95_14day_movavg  \
# 1632                     26.70                     26.81
# 1633                     25.83                     25.94
# 1634                     25.04                     25.15
# 1635                     24.45                     24.56
# 1636                     24.17                     24.28
#
#       At_home_p5_21day_movavg  At_home_avg_21day_movavg  \
# 1632                    27.11                     27.20
# 1633                    27.12                     27.21
# 1634                    26.77                     26.86
# 1635                    26.82                     26.91
# 1636                    26.67                     26.76
#
#       At_home_p95_21day_movavg  At_home_p5_28day_movavg  \
# 1632                     27.29                    27.78
# 1633                     27.31                    27.27
# 1634                     26.95                    26.87
# 1635                     27.00                    26.67
# 1636                     26.85                    26.42
#
#       At_home_avg_28day_movavg  At_home_p95_28day_movavg
# 1632                     27.86                     27.94
# 1633                     27.35                     27.43
# 1634                     26.95                     27.03
# 1635                     26.75                     26.83
# 1636                     26.50                     26.58
#
# [5 rows x 32 columns]

# %%
plt.plot(df[['Mean_distance_avg', 'Mean_distance_avg_14day_movavg']])
# Out:
# [<matplotlib.lines.Line2D at 0x229e7544b30>,
#  <matplotlib.lines.Line2D at 0x229e7544c50>]

# %%
df_full = pd.DataFrame()

for file in csv_files:
    country_name = file.split(".")[0]
    df_temp = pd.read_csv(path + file)
    df_temp = df_temp[['Date', 'Mean_distance_avg_14day_movavg']]
    df_temp['country'] = country_name
    df_full = pd.concat([df_full, df_temp], ignore_index=True)

# %%
df_full
# Out:
#             Date  Mean_distance_avg_14day_movavg country
# 0     2020-03-11                             NaN     CHL
# 1     2020-03-12                             NaN     CHL
# 2     2020-03-13                             NaN     CHL
# 3     2020-03-14                             NaN     CHL
# 4     2020-03-15                             NaN     CHL
# ...          ...                             ...     ...
# 9817  2024-08-29                           57.90     USA
# 9818  2024-08-30                           58.12     USA
# 9819  2024-08-31                           58.25     USA
# 9820  2024-09-01                           59.02     USA
# 9821  2024-09-02                           57.69     USA
#
# [9822 rows x 3 columns]

# %%
df_full.dropna(inplace = True)

# %%
df_full.to_csv('silver/mobility_index.csv', index = False)

# %%
# Convert 'Date' column to datetime if it's not already
df_full['Date'] = pd.to_datetime(df_full['Date'])

# Plotting
plt.figure(figsize=(14, 7))
sns.lineplot(data=df_full, x='Date', y='Mean_distance_avg_14day_movavg', hue='country')

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('Mean Distance (14-day Moving Average)')
plt.title('Mean Distance Over Time by Country')
plt.legend(title='Country')
plt.show()
